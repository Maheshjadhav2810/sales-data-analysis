# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_data.csv")

# %%
print(df.head())
# Out:
#   Month     Category Region  Sales
# 0   Jan  Electronics  North   5000
# 1   Feb    Furniture  South   3000
# 2   Mar     Clothing   East   4000
# 3   Apr  Electronics   West   6000
# 4   May    Furniture  North   3500

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     12 non-null     object
#  1   Category  12 non-null     object
#  2   Region    12 non-null     object
#  3   Sales     12 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 516.0+ bytes
# None

# %%
print(df.isnull().sum())
# Out:
# Month       0
# Category    0
# Region      0
# Sales       0
# dtype: int64

# %%
df = df.dropna()

# %%
total_sales = df["Sales"].sum()

print("Total Sales:", total_sales)
# Out:
# Total Sales: 54600

# %%
category_sales = df.groupby("Category")["Sales"].sum()

print(category_sales)
# Out:
# Category
# Clothing       16800
# Electronics    24500
# Furniture      13300
# Name: Sales, dtype: int64

# %%
sns.barplot(x=category_sales.index, y=category_sales.values)

plt.title("Sales by Category")

plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
sns.lineplot(x="Month", y="Sales", data=df)

plt.title("Monthly Sales Trend")

plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum()

# %%
plt.pie(region_sales, labels=region_sales.index, autopct="%1.1f%%")

plt.title("Sales Distribution by Region")

plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)

plt.title("Correlation Heatmap")

plt.show()
